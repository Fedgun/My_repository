# %%
import pandas as pd

test = pd.read_excel('data/rosstat.xlsx', header = [0,1,2], index_col = 0)

display(test)
# Out:
#                               Unnamed: 1_level_0  \
#                               Unnamed: 1_level_1
# все население                       w2:p_mest:11
# Российская Федерация                         643
# Центральный федеральный округ                 30
# Белгородская область                 14000000000
# Брянская область                     15000000000
# Владимирская область                 17000000000
# ...                                          ...
# Амурская область                     10000000000
# Магаданская область                  44000000000
# Сахалинская область                  64000000000
# Еврейская автономная область         99000000000
# Чукотский автономный округ           77000000000
#
#                               23110000100100200001 Общий прирост постоянного населения  \
#                                                                                2017 г.
# все население                                                       Unnamed: 2_level_2
# ...
