# %% [markdown]
# Рассмотрим, что представляет собой вектор в Python.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Мат. пояснения

# %% [markdown]
# - s - вектор
#
# - S - векторное пространство
#
# - R^2 - двумерное пространвсто действиетльных чисел (координатная 2D плоскость)
#
# - ![image.png](attachment:image.png) - вектор s принадлежит к части двусерного пространства дейтсвительных чисел
#
# - dim(s) - размерность вектора
#
# - ![image-2.png](attachment:image-2.png)
#
# - ![image-4.png](attachment:image-4.png)
#
# - ![image-3.png](attachment:image-3.png)
#
# - ![image-5.png](attachment:image-5.png)
#
# - ![image-6.png](attachment:image-6.png)
#
# - ![image-7.png](attachment:image-7.png)
#
# - ![image-8.png](attachment:image-8.png)
#
# - ![image-9.png](attachment:image-9.png)

# %% [markdown]
# ## Вектор в python

# %%
#Вызываем библиотеку numpy, т. к. именно в ней удобнее всего работать с векторами.

import numpy as np

# Задаём вектор s как одномерный массив numpy с помощью функции np.array.

s = np.array([33, 65, 50, 45])
s
# Out:
# array([33, 65, 50, 45])

# %%
# Находим третью координату.

print(s[2])

# Находим размерность вектора. За размерность отвечает функция len().

print(len(s))
# Out:
# 50
# 4

# %% [markdown]
# ### Задание 2.1
#
# Дан вектор в Python вида t = np.array([12, 14, 17, 19, 24, 28, 31, 31, 27, 22, 17, 13]), содержащий информацию о средней температуре воздуха (в градусах Цельсия) в Риме с января по декабрь включительно. Будем считать, что температура в январе — , то есть отсчёт индексов идёт с нуля.
#
# Выберите неверное утверждение:

# %%
t = np.array([12, 14, 17, 19, 24, 28, 31, 31, 27, 22, 17, 13])
t.min()
# Out:
# np.int64(12)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # БАЗОВЫЕ ОПЕРАЦИИ С ВЕКТОРАМИ

# %% [markdown]
# Внутри любого векторного пространства должны быть определены следующие операции с векторами:
#
# Сложение/вычитание векторов. Результат — вектор.
#
# Умножение вектора на скаляр (число). Результат — вектор.
#
# Линейная комбинация векторов. Результат — вектор.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## решение на python

# %%
a = np.array([10, 8, 5, 1])
b = np.array([5, 15, 9, 7])
print(a + b)
## array([15, 23, 14,  8])
print(a - b)
## array([ 5, -7, -4, -6])
# Out:
# [15 23 14  8]
# [ 5 -7 -4 -6]

# %% [markdown]
# ## Умножение вектора на скаляр

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Решение на Python

# %%
a = np.array([120, 45, 68])
omega = 0.2
c = a * omega
print(c)
## array([24. ,  9. , 13.6])
# Out:
# [24.   9.  13.6]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # *ГЕОМЕТРИЧЕСКАЯ ИНТЕРПРЕТАЦИЯ БАЗОВЫХ ОПЕРАЦИЙ С ВЕКТОРАМИ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### ЛИНЕЙНАЯ КОМБИНАЦИЯ ВЕКТОРОВ

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Решение на Python

# %%
p = np.array([2, 4, 5])
v = np.array([8, 10, 2])
s = np.array([0, 12, 7])
omega1 = 500
omega2 = 100
omega3 = 0
u = omega1*p + omega2*v + omega3*s
u
## array([1800, 3000, 2700])
# Out:
# array([1800, 3000, 2700])

# %% [markdown]
# ### Скалярное произведение векторов

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Решение на Python

# %%
a = np.array([65, 70, 120, 30])
w = np.array([0.4, 0.4, 0.2, 0.8])
np.dot(a, w) #функция скалярного произведения векторов
## 102.0
# Out:
# np.float64(102.0)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### *ВЕКТОРНАЯ ЗАПИСЬ МОДЕЛИ ЛИНЕЙНОЙ РЕГРЕССИИ
