# %% [markdown]
# ### Задание 1.1
#
# Найдите скалярное произведение векторов:

# %%
import numpy as np
x = np.array([-1,2,-7,9])
y = np.array([2,8,2,-1])
lx=np.linalg.norm(x.T)
ly = np.linalg.norm(y.T)
lx+ly
# Out:
# np.float64(20.16295378393978)

# %%
s=np.dot(x.T, y.T)
s
# Out:
# np.int64(-9)

# %% [markdown]
# ### Задание 1.4
#
# Найдите матрицу Грама G.
#
# Заполните текстовые поля слева направо, сверху вниз.

# %%
A = np.array([[1,1], [1,2]])
B = A.T
B@A
# Out:
# array([[2, 3],
#        [3, 5]])

# %% [markdown]
# ### Задание 1.5
#
# Определитель квадратной матрицы A равен 0. Что это означает?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Задание 1.6
#
# Вычислите обратную матрицу A(-1), если:

# %%
A = np.array([[1,2], [3,7]])
np.linalg.inv(A)
# Out:
# array([[ 7., -2.],
#        [-3.,  1.]])

# %% [markdown]
# ### Задание 1.7
#
# Найдите ранг матрицы системы, составленной из векторов:
#
# ![image.png](attachment:image.png)

# %%
v1 = np.array([2,10,-2])
v2 = np.array([3,2,-2])
v3 = np.array([8,14,-6])

# %%
vv = np.column_stack((v1,v2,v3))
np.linalg.matrix_rank(vv)
# Out:
# np.int64(2)

# %%
vv
# Out:
# array([[ 2,  3,  8],
#        [10,  2, 14],
#        [-2, -2, -6]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Задание 1.9
#
# Сколько нетривиальных решений имеет представленная ниже система уравнений?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
